# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
plt.title("Line plot ")
plt.xlabel(" x labels")
plt.ylabel(" y labels")

plt.plot(df['PassengerId'] .head(10),df['Fare'].head(10) , color = 'red', marker = 'o' , mfc = 'black', ls = '--');

plt.grid()

# %%
plt.title("Passenger Count ")
plt.xlabel('p class')
plt.ylabel('no. of passenger')
plt.bar(df['Pclass'].value_counts().index, df['Pclass'].value_counts() , color = 'orange', width = 0.4 , edgecolor = 'black');
plt.grid()

# %%
plt.figure(figsize = (12,5))
plt.hist(df['Age'], bins = 30 , color = 'pink' , edgecolor = 'black') 
plt.grid()

# %%
plt.title("Compare Age and Fare ")
plt.xlabel("age")
plt.ylabel("fare")
plt.scatter( df['Age'],df['Fare'] , marker = '*' , mar)
plt.grid()
